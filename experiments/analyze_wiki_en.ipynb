# %% [markdown]
# # Analyze English WIKIPEDIA Corpus

# %%
from rwse_checker.rwse import RWSE_Checker
from transformers import AutoTokenizer
from helper import check_token

import os
import pandas as pd
import spacy

# %%
rwse = RWSE_Checker()
nlp = spacy.load('en_core_web_sm')
# Out:
# BertForMaskedLM has generative capabilities, as `prepare_inputs_for_generation` is explicitly overwritten. However, it doesn't directly inherit from `GenerationMixin`. From 👉v4.50👈 onwards, `PreTrainedModel` will NOT inherit from `GenerationMixin`, and this model will lose the ability to call `generate` and other related functions.
#   - If you're using `trust_remote_code=True`, you can get rid of this warning by loading the model with an auto class. See https://huggingface.co/docs/transformers/en/model_doc/auto#auto-classes
#   - If you are the owner of the model architecture code, please modify your model class such that it inherits from `GenerationMixin` (after `PreTrainedModel`, otherwise you'll get an exception).
#   - If you are not the owner of the model architecture class, please contact the model code owner to update it.
# Some weights of the model checkpoint at bert-base-cased were not used when initializing BertForMaskedLM: ['bert.pooler.dense.bias', 'bert.pooler.dense.weight', 'cls.seq_relationship.bias', 'cls.seq_relationship.weight']
# - This IS expected if you are initializing BertForMaskedLM from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForMaskedLM from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Device set to use cpu

# %% [markdown]
# ## Cleaning

# %%
collection = dict()
with open('input/dataset_semantic_en_simple.txt', 'r') as f:
    result = []
    idx = 0
    for line in f:
        if line == "\n":
            collection[idx] = result
            idx += 1
            result = []
        else:
            result.append(line.strip())

len(collection)
# Out:
# 448

# %%
collection[0]
# Out:
# ['27',
#  '1298315',
#  'goals',
#  'jails',
#  '223',
#  'Often they were sent away to the British Colonies in America. But in 1770, the colonies in America became the United States. They were free from British rule and would not take England s convicts any more. By the 1780s the goals of England were so full that convicts were often chained up in rotting old ships.The Government decided to make a settlement in New South Wales and send some of the convicts there. In 1788 the First Fleet of eleven ships set sail from Portsmouth carrying convicts, sailors, marines, a few free settlers and enough food to last for two years. Their leader was Captain Arthur Phillip.']

# %%
file_name = 'input/cleaned_dataset_semantic_en.csv'

def clean_text(text):
    text = '. '.join([part.strip() for part in text.split('.')]).strip()
    text = '. '.join([part.strip() for part in text.split('?')]).strip()
    return text

def find_sentence(token_text, token_start, text):
    tmp_doc = nlp(clean_text(text))
    for sent in tmp_doc.sents:
        if sent.start_char <= token_start < sent.end_char:
            for tmp_token in sent:
                if tmp_token.text == token_text:
                    tmp_start = tmp_token.idx - sent.start_char
                    tmp_end = tmp_start + len(tmp_token.text)
                    return sent.text[:tmp_start] + '[MASK]' + sent.text[tmp_end:]
    return None

if not os.path.exists(file_name):

    checkpoint = 'bert-base-cased'
    tokenizer = AutoTokenizer.from_pretrained(checkpoint)

    cleaned_collection_semantic = []
    bad_words = []
    bad_indices = []
    for key, value in collection.items():
        item = {
            'org_index': int(value[1]),
            'org_token': value[2],
            'org_suggestion': value[3],
            'confusion_set': f'{",".join(sorted([value[2],value[3]]))}',
            'text': find_sentence(value[2], int(value[4]), ' '.join(value[5:]))
        }
        if check_token(tokenizer, item['org_token']) is None:
            bad_words.append(item['org_token'])
        elif check_token(tokenizer, item['org_suggestion']) is None:
            bad_words.append(item['org_suggestion'])
        elif item['text'] is None:
            bad_indices.append(item['org_index'])
        else:
            cleaned_collection_semantic.append(item)


    cleaned_collection_semantic = pd.DataFrame.from_dict(cleaned_collection_semantic)
    for confusion_set in cleaned_collection_semantic['confusion_set'].unique():
        indices = cleaned_collection_semantic[cleaned_collection_semantic['confusion_set'] == confusion_set].index
        if len(indices) == 2:
            cleaned_collection_semantic.drop(min(indices), inplace=True)
    cleaned_collection_semantic.to_csv(file_name, index=False, sep='\t')
    pd.DataFrame(bad_words).to_csv(file_name+'-bad_words', index=False, header=None, sep='\t')
    pd.DataFrame(bad_indices).to_csv(file_name+'-bad_indices', index=False, header=None, sep='\t')
else:
    cleaned_collection_semantic = pd.read_csv(file_name, sep='\t')

cleaned_collection_semantic
# Out:
#      org_index  org_token org_suggestion          confusion_set  \
# 0       208822       were           wear              wear,were
# 1       524374     affect         effect          affect,effect
# 2      1137524    website       websites       website,websites
# 3        16804       work           word              word,work
# 4       321273       main          major             main,major
# ..         ...        ...            ...                    ...
# 101    1002353       easy           east              east,easy
# 102    1150628      honey          money            honey,money
# 103     502090       park           part              park,part
# 104    1109051  saxophone    saxophonist  saxophone,saxophonist
# 105     333224       spit          split             spit,split
#
#                                                   text
# 0    When dancing ballet, you are required to [MASK...
# 1    The Atlantic has a large [MASK] in the north a...
# 2    Google is one of the biggest and most famous [...
# 3    Its name comes from the Greek [MASK] for Sun, ...
# 4    In many countries throughout history, religion...
# ..                                                 ...
# 101        The [MASK] mainly spoke the Greek language.
# 102  People who had bad things happen to them or wh...
# 103  The electrode is made of the same kind of meta...
# 104  Charlie Parker born August 29, 1920 in Kansas ...
# 105  Primates are [MASK] into two groups simians an...
#
# [106 rows x 5 columns]

# %% [markdown]
# ## Analysis

# %%
file_name = 'output/report_dataset_semantic_en.csv'
input_file_name = 'input/modified_dataset_semantic_en.csv'

if not os.path.exists(file_name):
    data = pd.read_csv(input_file_name, sep='\t')
    with (open(file_name, 'w') as f):
        print('result_fw', 'result_bw', 'index' ,'org_token', 'org_suggestion', 'masked_sentence', sep='\t', end='\n', file=f)
        for index, item in data.iterrows():
            org_token = item['org_token']
            org_suggestion = item['org_suggestion']
            sentence = item['text']

            rwse.set_confusion_sets([item['confusion_set'].split(',')])
            suggestion, certainty = rwse.check(org_token, sentence)
            # Used in miss rate analysis
            result_fw = 'TP' if suggestion == org_suggestion else 'FN'

            # Switch tokens
            org_token, org_suggestion = org_suggestion, org_token
            suggestion, certainty = rwse.check(org_token, sentence)
            # Used in false-alarm rate analysis
            result_bw = 'FP' if suggestion == org_suggestion else 'TN'

            print(result_fw, result_bw, item['org_index'], item['org_token'], item['org_suggestion'], sentence, sep='\t', end='\n', file=f)

classification_results = pd.read_csv(file_name, sep='\t')
classification_results
# Out:
#    result_fw result_bw    index   org_token org_suggestion  \
# 0         TP        TN   208822        were           wear
# 1         TP        TN   524374      affect         effect
# 2         TP        TN    16804        work           word
# 3         FN        TN   341582       bitch          pitch
# 4         FN        TN  1250703        weed          wheat
# 5         TP        TN   343890         art           part
# 6         FN        TN   656168        mile           milk
# 7         TP        TN   708056       crack           back
# 8         TP        TN   103691        seal           meal
# 9         TP        TN   350785     monkeys          monks
# 10        FN        TN   211968       steam          siege
# 11        TP        TN    28378        king           kind
# 12        TP        TN   113165     effects        affects
# 13        FN        FP   147342      castle          caste
# 14        TP        TN   325250       whole           hole
# 15        TP        TN   668219      brakes         breaks
# 16        TP        TN    87643      forums          forms
# 17        TP        TN   333917       found        founded
# 18        TP        TN   408431       loose           lose
# 19        TP        TN   139324        bank           band
# 20        TP        TN  1037068     brought         bought
# 21        TP        TN   142927      desert        dessert
# 22        FN        FP   484398        cord          chord
# 23        TP        TN   487171   depressed        pressed
# 24        TP        TN    21466       night          light
# 25        TP        TN    62139    starting       starring
# 26        TP        TN    47551   insisting     consisting
# 27        TP        TN   737736        site          sight
# 28        TP        TN    89921         run            fun
# 29        TP        TN   471817    erection       eruption
# 30        TP        TN  1215169       plane          plain
# 31        TP        TN   989684      trunks         trucks
# 32        TP        TN   195975        crap           crab
# 33        TP        TN   186281      cooled         called
# 34        FN        FP    55424        mean           meal
# 35        TP        TN    60247       trail          trial
# 36        TP        TN   126570         ear           year
# 37        TP        TN  1129244       brake          break
# 38        TP        TN   309490        ears          years
# 39        TP        TN    64655         tow           town
# 40        TP        TN   194815      office        officer
# 41        TP        TN   928351  compliment     complement
# 42        FN        FP   794884        fund          found
# 43        TP        TN   657934        dick           duck
# 44        TP        TN   937722       stars         starts
# 45        TP        TN  1002353        easy           east
# 46        TP        TN  1150628       honey          money
# 47        TP        TN   502090        park           part
# 48        TP        TN   333224        spit          split
#
#                                       masked_sentence
# 0   When dancing ballet, you are required to [MASK...
# 1   The Atlantic has a large [MASK] in the north a...
# 2   Its name comes from the Greek [MASK] for Sun, ...
# 3   There are four things which music often has Mu...
# 4   One person who owned many cows could trade wit...
# 5   Leaving Canada Quebec was [MASK] of New France...
# 6        But still keeping the chocloate [MASK] away.
# 7       They also have a dark line down their [MASK].
# 8   There is also informal education, for example,...
# 9   History The first people who lived on Iceland ...
# 10  Some of these machines were called catapults o...
# 11  History of paper Many centuries ago as early a...
# 12            Energy from the sun [MASK] the weather.
# 13  He would not keep his wife, his child, his wea...
# 14  You take it and put it in the groud and pick u...
# 15  Another example is Protease, protease is used ...
# 16  A fuel is a substance that is burned to produc...
# 17  Arthur Phillip was born in Britain and [MASK] ...
# 18  Dudley was an ambitious man and realised that ...
# 19  Personal life Gwyneth was married to Chris Mar...
# 20  It can be bought at shops and normally comes w...
# 21  The traditional meal served at Phillippe s is ...
# 22               It is a member of the [MASK] family.
# 23  Typo P instead of O and hitting Z when shift i...
# 24  Animals are being endangered every day, just b...
# 25  Douglas aslo was known for his humorous detect...
# 26  The Who are a popular British rock group [MASK...
# 27          In Korea Kimchi Pots are a common [MASK].
# 28  Fishing for fun Fishing for [MASK] is normally...
# 29  Eruption of 79 Today, people think the [MASK] ...
# 30                Trikala is built on a large [MASK].
# 31  Also, the track spreads the weight of the trai...
# 32  Eugene H. Krabs a [MASK] who is the creator of...
# 33  The idea that something can be split into many...
# 34  Sometimes, especially in the Southern United S...
# 35                  In 2005 there was another [MASK].
# 36  Inflation is measured each [MASK], and the inf...
# 37  Uses of anthrax Anthrax is generally used with...
# 38  Several [MASK] earlier adopters and developers...
# 39             Coesfeld has been a [MASK] since 1197.
# 40  A police [MASK] typically wears a police suit,...
# 41  mRNA mRNA, or Messenger RNA is the [MASK] stra...
# 42  He left instructions in his will that his mone...
# 43  Especially in Asia, many people like to eat [M...
# 44           After that it [MASK] to tumble and drop.
# 45        The [MASK] mainly spoke the Greek language.
# 46  People who had bad things happen to them or wh...
# 47  The electrode is made of the same kind of meta...
# 48  Primates are [MASK] into two groups simians an...

# %%
summarized_results = {
    'TP': len(classification_results[classification_results['result_fw'] == 'TP']),
    'FN': len(classification_results[classification_results['result_fw'] == 'FN']),
    'TN': len(classification_results[classification_results['result_bw'] == 'TN']),
    'FP': len(classification_results[classification_results['result_bw'] == 'FP']),
}
print(summarized_results)

false_alarm_rate = summarized_results['FP']/len(classification_results)
print(f'false-alarm rate: {false_alarm_rate:.3f}')

miss_rate = summarized_results['FN']/len(classification_results)
print(f'miss rate: {miss_rate:.3f}')

accuracy = (summarized_results['TP']+summarized_results['TN'])/(len(classification_results) * 2)
print(f'accuracy: {accuracy:.3f}')
# Out:
# {'TP': 41, 'FN': 8, 'TN': 45, 'FP': 4}
# false-alarm rate: 0.082
# miss rate: 0.163
# accuracy: 0.878
